# %%
# !pwd
# %cd /content
# Out:
# /content
# /content

# %% [markdown]
# 1. 현재 작업 중인 디렉토리(폴더)의 절대 경로를 출력
#
# 2. 작업 디렉토리를 '/content' 폴더로 변경(이동)
# (구글 코랩의 기본 기본 작업 디렉토리가 바로 이 /content)

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="XV2VXlg2vDD4ouTjUaWz")
project = rf.workspace("s-workspace-rvhaf").project("2026_07_21")
version = project.version(1)
dataset = version.download("yolov5", location="/content/yolo_dataset")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %% [markdown]
# 1. Roboflow API를 사용하기 위해 필요한 전용 라이브러리를 설치
#
# 2. 설치한 Roboflow 라이브러리를 불러.
#
# 3. 발급받은 개인 API 키를 입력하여 Roboflow 계정 인증을 진행.
#
# 4. 해당 프로젝트에서 학습에 사용할 첫 번째 버전(v1)의 데이터셋을 선택
#
# 5. 선택한 데이터를 YOLOv5 모델 학습 형식에 맞춰 코랩의 /content/yolo_dataset 폴더로 다운로드

# %%
import yaml

# 2. 파일 읽기/쓰기 및 데이터 경로도 모두 yolo_dataset으로 변경
with open('/content/yolo_dataset/data.yaml', 'r') as f:
  data = yaml.load(f, Loader=yaml.FullLoader)

data['train'] = '/content/yolo_dataset/train/images'
data['val'] = '/content/yolo_dataset/valid/images'
data['test'] = '/content/yolo_dataset/test/images'

with open('/content/yolo_dataset/data.yaml', 'w') as f:
  yaml.dump(data, f)
print(data)
# Out:
# {'names': ['circle', 'square'], 'nc': 2, 'roboflow': {'license': 'CC BY 4.0', 'project': 20260721, 'url': 'https://universe.roboflow.com/s-workspace-rvhaf/2026_07_21/dataset/1', 'version': 1, 'workspace': 's-workspace-rvhaf'}, 'test': '/content/yolo_dataset/test/images', 'train': '/content/yolo_dataset/train/images', 'val': '/content/yolo_dataset/valid/images'}

# %% [markdown]
# 1. Python에서 YAML 형식의 설정 파일을 읽고 쓰기 위한 라이브러리를 불러옴
#
# 2. 다운로드받은 데이터셋 안에 포함된 data.yaml 파일을 읽기('r') 모드로 안전하게 염
#
# 3. YAML 파일 내부의 텍스트 데이터를 Python이 이해할 수 있는 딕셔너리 형태로 변환하여 data 변수에 저장
#
# 4. YOLOv5 모델이 학습할 때 사용할 훈련용(Train) 이미지들이 들어있는 절대 경로로 수정
#
# 5. 모델 성능을 검증할 때 사용할 검증용(Validation) 이미지들이 들어있는 절대 경로로 수정
#
# 6. 최종 평가에 사용할 테스트용(Test) 이미지들이 들어있는 절대 경로로 수정
#
# 7. 경로 수정이 완료된 데이터를 다시 저장하기 위해 data.yaml 파일을 쓰기('w') 모드로
#
# 8. Python 딕셔너리에 저장된 수정 데이터를 실제 data.yaml 파일에 다시 텍스트 형태로 덮어씀
#
# 9. 경로가 올바르게 업데이트되었는지 콘솔 창에 출력하여 눈으로 최종 확인

# %%
# %cd /content
# !git clone https://github.com/ultralytics/yolov5.git
# %cd yolov5
! pip install -r requirements.txt
# Out:
# /content
# fatal: destination path 'yolov5' already exists and is not an empty directory.
# /content/yolov5
# ...

# %% [markdown]
# 1.작업 디렉토리를 코랩의 기본 폴더인 /content로 변경(이동)
#
# 2.깃허브(GitHub)에 공개된 Ultralytics 사의 최신 YOLOv5 공식 소스코드 저장소를 그대로 다운로드
#
# 3.방금 다운로드하여 새로 생성된 yolov5 폴더 내부로 작업 디렉토리를 이동
#
# 4.YOLOv5 모델을 실행하고 학습시키는 데 필요한 패키지 목록(requirements.txt)을 읽어와 관련 외부 라이브러리들을 한 번에 설치

# %%
# !python /content/yolov5/train.py --img 640 --batch 16 --epochs 50 --data /content/yolo_dataset/data.yaml --weights yolov5x.pt --name result --cfg /content/yolov5/models/yolov5x.yaml
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: (30 second timeout)
# wandb: WARNING W&B disabled due to login timeout.
# wandb: W&B API key is configured. Use `wandb login --relogin` to force relogin
# ...

# %% [markdown]
# 1. YOLOv5의 train.py 스크립트를 사용하여
# 2. 대형 모델인 YOLOv5x 구조(--cfg)에 미리 학습된 가중치(--weights)를 불러온 뒤,
# 3. 이미지 크기 640(--img),
# 4. 배치 크기 16(--batch),
# 5. 50회 반복(--epochs)
# 6. 데이터셋(--data)을 학습시켜 그 결과를 'result' 폴더(--name)에 저장하는 명령

# %%
# !python detect.py --weights /content/yolov5/runs/train/result/weights/best.pt --source /content/yolo_dataset/test/images --img-size 640 --conf 0.4
# Out:
# detect: weights=['/content/yolov5/runs/train/result/weights/best.pt'], source=/content/yolo_dataset/test/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-519-g6be609f3 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
#
# Fusing layers...
# YOLOv5x summary: 322 layers, 86180143 parameters, 0 gradients, 203.8 GFLOPs
# image 1/18 /content/yolo_dataset/test/images/circle_14_png.rf.2e1c0626093b595ab48218580b36cafa.jpg: 640x640 1 circle, 79.0ms
# image 2/18 /content/yolo_dataset/test/images/circle_16_png.rf.51b74980a01d5f0763008c5a1d49e12a.jpg: 640x640 1 circle, 52.8ms
# ...

# %% [markdown]
# 1. YOLOv5의 detect.py 스크립트를 사용하여
# 2. 학습을 통해 저장된 최적의 가중치 파일(--weights)을 불러온 뒤,
# 3. 지정된 테스트용 이미지 폴더(--source) 속 데이터들을 대상으로
# 4.이미지 크기 640(--img-size),
# 5.신뢰도 임계값 0.4(--conf) 설정 조건에 맞춰 객체 탐지를 수행하는 명령
